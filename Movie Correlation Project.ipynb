# %%
#Import Libraries 
import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)

pd.options.mode.chained_assignment = None

# %%
#Read the data 
df = pd.read_csv('/content/sample_data/movies.csv')

# %%
df.head()
# Out:
#                                              name  ... runtime
# 0                                     The Shining  ...   146.0
# 1                                 The Blue Lagoon  ...   104.0
# 2  Star Wars: Episode V - The Empire Strikes Back  ...   124.0
# 3                                       Airplane!  ...    88.0
# 4                                      Caddyshack  ...    98.0
#
# [5 rows x 15 columns]

# %%
#Incase of missing data 
for col in df.columns:
  pct_missing = np.mean(df[col].isnull())
  print('{} - {}%'.format(col,pct_missing))
# Out:
# name - 0.0%
# rating - 0.010041731872717789%
# genre - 0.0%
# year - 0.0%
# released - 0.0002608242044861763%
# score - 0.0003912363067292645%
# votes - 0.0003912363067292645%
# director - 0.0%
# writer - 0.0003912363067292645%
# star - 0.00013041210224308815%
# country - 0.0003912363067292645%
# budget - 0.2831246739697444%
# gross - 0.02464788732394366%
# company - 0.002217005738132499%
# runtime - 0.0005216484089723526%

# %%
#Data types 
df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
df
# Out:
#                                                 name  ... runtime
# 0                                        The Shining  ...   146.0
# 1                                    The Blue Lagoon  ...   104.0
# 2     Star Wars: Episode V - The Empire Strikes Back  ...   124.0
# 3                                          Airplane!  ...    88.0
# 4                                         Caddyshack  ...    98.0
# ...                                              ...  ...     ...
# 7663                                    More to Life  ...    90.0
# 7664                                     Dream Round  ...    90.0
# 7665                                   Saving Mbango  ...     NaN
# 7666                                    It's Just Us  ...   120.0
# 7667                                       Tee em el  ...   102.0
#
# [7668 rows x 15 columns]

# %%
 df= df.sort_values(by=['gross'], inplace=False, ascending=False)

# %%
pd.set_option('display.max_rows', None)

# %%
#dropping duplicate columns 
df['company'].drop_duplicates().sort_values(ascending=False)
# Out:
# 7129                                              thefyzz
# 5664                                          micro_scope
# 6412                             iDeal Partners Film Fund
# 4007                                             i5 Films
# 6793                                           i am OTHER
# 6420                                                 erbp
# 3776                                       double A Films
# 524                             Zupnik-Curtis Enterprises
# 3330                          Zucker Brothers Productions
# 146                                      Zoetrope Studios
# 2213                                   Zeta Entertainment
# 6222                        Zentropa International Norway
# 3368                              Zentropa Entertainments
# 535                                  Zenith Entertainment
# 5180                                      Zazen Produções
# 3193                                          ZapPictures
# ...

# %%
#Scatterplot with budget v/s gross 

plt.scatter(x=df['budget'], y=df['gross'])
plt.title('Budget v/s Gross Revenues')
plt.xlabel('Gross Revenues')
plt.ylabel('Movie Budget')
plt.show()

# %%
#Plot the Budget v/s Gross revenues using seaborn

sns.regplot(x='budget', y='gross', data=df, scatter_kws={"color": "red"}, line_kws={"color":"blue"})

# %%
#Determining correlations
df.corr(method='pearson') #types of correlations - pearson, spearman and kendall
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.099045  0.469829  0.317336  0.293084  0.142977
# score    0.099045  1.000000  0.428138 -0.001403  0.126116  0.399857
# votes    0.469829  0.428138  1.000000  0.502466  0.742050  0.290159
# budget   0.317336 -0.001403  0.502466  1.000000  0.693670  0.336370
# gross    0.293084  0.126116  0.742050  0.693670  1.000000  0.246243
# runtime  0.142977  0.399857  0.290159  0.336370  0.246243  1.000000

# %%
coorelation_matrix = df_numerized.corr(method='pearson')
plt.title('Correlations')
sns.heatmap(coorelation_matrix, annot=True)
plt.show()

# %%
correlation_mat = df_numerized.corr()
corr_pairs = correlation_mat.unstack()
sorted_pairs = corr_pairs.sort_values()
sorted_pairs
# Out:
# genre         budget         -0.356564
# budget        genre          -0.356564
# genre         gross          -0.235650
# gross         genre          -0.235650
# rating        budget         -0.176002
# budget        rating         -0.176002
# votes         genre          -0.145307
# genre         votes          -0.145307
# score         country        -0.133348
# country       score          -0.133348
# correct year  budget         -0.110181
# budget        correct year   -0.110181
# rating        gross          -0.107339
# gross         rating         -0.107339
# correct year  gross          -0.103372
# gross         correct year   -0.103372
# genre         year           -0.081261
# year          genre          -0.081261
# runtime       country        -0.078412
# country       runtime        -0.078412
# company       genre          -0.071067
# genre         company        -0.071067
# country       year           -0.070938
# year          country        -0.070938
# ...

# %%
high_corr = sorted_pairs[(sorted_pairs)>0.5]
high_corr
# Out:
# votes         gross           0.630757
# gross         votes           0.630757
#               budget          0.740395
# budget        gross           0.740395
# name          name            1.000000
# company       company         1.000000
# gross         gross           1.000000
# budget        budget          1.000000
# country       country         1.000000
# star          star            1.000000
# writer        writer          1.000000
# director      director        1.000000
# votes         votes           1.000000
# score         score           1.000000
# released      released        1.000000
# year          year            1.000000
# genre         genre           1.000000
# rating        rating          1.000000
# runtime       runtime         1.000000
# correct year  correct year    1.000000
# dtype: float64

# %%
#Votes and Budget have the closest correlation to the gross revenues 
#Company has the lowest correlation
